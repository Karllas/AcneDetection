# %% [markdown]
# # Hello ailia SDK!

# %% [markdown]
# - [Open with Colab](https://colab.research.google.com/github/axinc-ai/ailia-models/blob/master/hello_ailia.ipynb)

# %% [markdown]
# In this tutorial, we install the ailia SDK and ailia MODELS, and perform object detection using yolox.

# %%
# !pip3 install ailia
# !git clone --depth 1 https://github.com/axinc-ai/ailia-models
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 15.0 MB/s eta 0:00:00
# ...
# Cloning into 'ailia-models'...
# remote: Enumerating objects: 3499, done.
# remote: Counting objects: 100% (3499/3499), done.
# remote: Compressing objects: 100% (3004/3004), done.
# remote: Total 3499 (delta 553), reused 2468 (delta 408), pack-reused 0 (from 0)
# Receiving objects: 100% (3499/3499), 674.57 MiB | 29.03 MiB/s, done.
# Resolving deltas: 100% (553/553), done.
# Updating files: 100% (3240/3240), done.

# %%
# light
# !pip3 install opencv-python numpy
# full
#!pip3 install -r ailia-models/requirements.txt

# %%
# !cd ailia-models/image_segmentation/pspnet-hair-segmentation && python3 pspnet-hair-segmentation.py -i hair.jpeg
# Out:
#  INFO arg_utils.py (13) : Start!
#  INFO arg_utils.py (163) : env_id: 1
#  INFO arg_utils.py (166) : CPU-IntelMKL
#  INFO model_utils.py (89) : ONNX file and Prototxt file are prepared!
#  INFO license.py (85) : Welcome to ailia! The ailia SDK is a commercial library. Under certain conditions, it can be used free of charge; however, it is principally paid software. For details, please refer to https://ailia.ai/license/ .
#  INFO pspnet-hair-segmentation.py (106) : hair.jpeg
#  INFO pspnet-hair-segmentation.py (114) : Start inference...
#  INFO pspnet-hair-segmentation.py (134) : saved at : output.png
# Traceback (most recent call last):
#   File "/content/ailia-models/image_segmentation/pspnet-hair-segmentation/pspnet-hair-segmentation.py", line 215, in <module>
#     main()
#   File "/content/ailia-models/image_segmentation/pspnet-hair-segmentation/pspnet-hair-segmentation.py", line 211, in main
#     recognize_from_image(net, img_size)
# ...

# %%
from IPython import display
display.Image("ailia-models/image_segmentation/pspnet-hair-segmentation/output.png")
